# %% [markdown]
# # Project: Train a Quadcopter How to Fly
#
# Design an agent to fly a quadcopter, and then train it using a reinforcement learning algorithm of your choice!
#
# Try to apply the techniques you have learnt, but also feel free to come up with innovative ideas and test them.

# %% [markdown]
# ## Instructions
#
# Take a look at the files in the directory to better understand the structure of the project.
#
# - `task.py`: Define your task (environment) in this file.
# - `agents/`: Folder containing reinforcement learning agents.
#     - `policy_search.py`: A sample agent has been provided here.
#     - `agent.py`: Develop your agent here.
# - `physics_sim.py`: This file contains the simulator for the quadcopter.  **DO NOT MODIFY THIS FILE**.
#
# For this project, you will define your own task in `task.py`.  Although we have provided a example task to get you started, you are encouraged to change it.  Later in this notebook, you will learn more about how to amend this file.
#
# You will also design a reinforcement learning agent in `agent.py` to complete your chosen task.
#
# You are welcome to create any additional files to help you to organize your code.  For instance, you may find it useful to define a `model.py` file defining any needed neural network architectures.
#
# ## Controlling the Quadcopter
#
# We provide a sample agent in the code cell below to show you how to use the sim to control the quadcopter.  This agent is even simpler than the sample agent that you'll examine (in `agents/policy_search.py`) later in this notebook!
#
# The agent controls the quadcopter by setting the revolutions per second on each of its four rotors.  The provided agent in the `Basic_Agent` class below always selects a random action for each of the four rotors.  These four speeds are returned by the `act` method as a list of four floating-point numbers.
#
# For this project, the agent that you will implement in `agents/agent.py` will have a far more intelligent method for selecting actions!

# %%
import random

class Basic_Agent():
    def __init__(self, task):
        self.task = task
    
    def act(self):
        new_thrust = random.gauss(450., 25.)
        return [new_thrust + random.gauss(0., 1.) for x in range(4)]

# %% [markdown]
# Run the code cell below to have the agent select actions to control the quadcopter.
#
# Feel free to change the provided values of `runtime`, `init_pose`, `init_velocities`, and `init_angle_velocities` below to change the starting conditions of the quadcopter.
#
# The `labels` list below annotates statistics that are saved while running the simulation.  All of this information is saved in a text file `data.txt` and stored in the dictionary `results`.

# %%
# %load_ext autoreload
# %autoreload 2

import csv
import numpy as np
from task import Task

# Modify the values below to give the quadcopter a different starting position.
runtime = 5.                                     # time limit of the episode
init_pose = np.array([0., 0., 10., 0., 0., 0.])  # initial pose
init_velocities = np.array([0., 0., 0.])         # initial velocities
init_angle_velocities = np.array([0., 0., 0.])   # initial angle velocities
file_output = 'data.csv'                         # file name for saved results

# Setup
task = Task(init_pose, init_velocities, init_angle_velocities, runtime)
agent = Basic_Agent(task)
done = False
labels = ['time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity',
          'psi_velocity', 'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)
    while True:
        rotor_speeds = agent.act()
        _, _, done = task.step(rotor_speeds)
        to_write = [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) + list(rotor_speeds)
        for ii in range(len(labels)):
            results[labels[ii]].append(to_write[ii])
        writer.writerow(to_write)
        if done:
            break

# %% [markdown]
# Run the code cell below to visualize how the position of the quadcopter evolved during the simulation.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(results['time'], results['x'], label='x')
plt.plot(results['time'], results['y'], label='y')
plt.plot(results['time'], results['z'], label='z')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# The next code cell visualizes the velocity of the quadcopter.

# %%
plt.plot(results['time'], results['x_velocity'], label='x_velocity')
plt.plot(results['time'], results['y_velocity'], label='y_velocity')
plt.plot(results['time'], results['z_velocity'], label='z_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Next, you can plot the Euler angles (the rotation of the quadcopter over the $x$-, $y$-, and $z$-axes),

# %%
plt.plot(results['time'], results['phi'], label='phi')
plt.plot(results['time'], results['theta'], label='theta')
plt.plot(results['time'], results['psi'], label='psi')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# before plotting the velocities (in radians per second) corresponding to each of the Euler angles.

# %%
plt.plot(results['time'], results['phi_velocity'], label='phi_velocity')
plt.plot(results['time'], results['theta_velocity'], label='theta_velocity')
plt.plot(results['time'], results['psi_velocity'], label='psi_velocity')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# Finally, you can use the code cell below to print the agent's choice of actions.

# %%
plt.plot(results['time'], results['rotor_speed1'], label='Rotor 1 revolutions / second')
plt.plot(results['time'], results['rotor_speed2'], label='Rotor 2 revolutions / second')
plt.plot(results['time'], results['rotor_speed3'], label='Rotor 3 revolutions / second')
plt.plot(results['time'], results['rotor_speed4'], label='Rotor 4 revolutions / second')
plt.legend()
_ = plt.ylim()

# %% [markdown]
# When specifying a task, you will derive the environment state from the simulator.  Run the code cell below to print the values of the following variables at the end of the simulation:
# - `task.sim.pose` (the position of the quadcopter in ($x,y,z$) dimensions and the Euler angles),
# - `task.sim.v` (the velocity of the quadcopter in ($x,y,z$) dimensions), and
# - `task.sim.angular_v` (radians/second for each of the three Euler angles).

# %%
# the pose, velocity, and angular velocity of the quadcopter at the end of the episode
print(task.sim.pose)
print(task.sim.v)
print(task.sim.angular_v)
# Out:
# [ 22.98274013 -28.1714676   17.07694482   4.59735436   5.21567401
#    0.        ]
# [ 30.59175627 -29.31486207  -4.21172557]
# [-1.09309846 -0.72254325  0.        ]

# %% [markdown]
# In the sample task in `task.py`, we use the 6-dimensional pose of the quadcopter to construct the state of the environment at each timestep.  However, when amending the task for your purposes, you are welcome to expand the size of the state vector by including the velocity information.  You can use any combination of the pose, velocity, and angular velocity - feel free to tinker here, and construct the state to suit your task.
#
# ## The Task
#
# A sample task has been provided for you in `task.py`.  Open this file in a new window now.
#
# The `__init__()` method is used to initialize several variables that are needed to specify the task.
# - The simulator is initialized as an instance of the `PhysicsSim` class (from `physics_sim.py`).
# - Inspired by the methodology in the original DDPG paper, we make use of action repeats.  For each timestep of the agent, we step the simulation `action_repeats` timesteps.  If you are not familiar with action repeats, please read the **Results** section in [the DDPG paper](https://arxiv.org/abs/1509.02971).
# - We set the number of elements in the state vector.  For the sample task, we only work with the 6-dimensional pose information.  To set the size of the state (`state_size`), we must take action repeats into account.
# - The environment will always have a 4-dimensional action space, with one entry for each rotor (`action_size=4`). You can set the minimum (`action_low`) and maximum (`action_high`) values of each entry here.
# - The sample task in this provided file is for the agent to reach a target position.  We specify that target position as a variable.
#
# The `reset()` method resets the simulator.  The agent should call this method every time the episode ends.  You can see an example of this in the code cell below.
#
# The `step()` method is perhaps the most important.  It accepts the agent's choice of action `rotor_speeds`, which is used to prepare the next state to pass on to the agent.  Then, the reward is computed from `get_reward()`.  The episode is considered done if the time limit has been exceeded, or the quadcopter has travelled outside of the bounds of the simulation.
#
# In the next section, you will learn how to test the performance of an agent on this task.

# %% [markdown]
# ## The Agent
#
# The sample agent given in `agents/policy_search.py` uses a very simplistic linear policy to directly compute the action vector as a dot product of the state vector and a matrix of weights. Then, it randomly perturbs the parameters by adding some Gaussian noise, to produce a different policy. Based on the average reward obtained in each episode (`score`), it keeps track of the best set of parameters found so far, how the score is changing, and accordingly tweaks a scaling factor to widen or tighten the noise.
#
# Run the code cell below to see how the agent performs on the sample task.

# %%
import sys
import pandas as pd
from agents.policy_search import PolicySearch_Agent
from task import Task

num_episodes = 1000

init_pos = np.array([0., 0., 1., 0., 0., 0.])
init_velocities = np.array([0., 0., 0.])
init_angle_velocities = np.array([0., 0., 0.])
target_pos = np.array([0., 0., 10.])
task = Task(init_pose, init_velocities, init_angle_velocities, target_pos=target_pos)

agent = PolicySearch_Agent(task)

labels = ['i_episode', 'total_reward', 'score', 'time', 'x', 'y', 'z', 'phi', 'theta', 'psi', 'x_velocity',
          'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity', 'psi_velocity',
          'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x : [] for x in labels}
results_last_episode = {x : [] for x in labels}

for i_episode in range(1, num_episodes+1):
    state = agent.reset_episode() # start a new episode
    while True:
        action = agent.act(state) 
        next_state, reward, done = task.step(action)
        agent.step(reward, done)
        state = next_state
        if i_episode == num_episodes:
            result = [i_episode] + [agent.total_reward] + [agent.score] \
                   + [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) \
                   + list(action)
            for ii in range(len(labels)):
                results_last_episode[labels[ii]].append(result[ii])
        if done:
            print("\rEpisode = {:4d}, score = {:7.3f} (best = {:7.3f}), noise_scale = {}".format(
                i_episode, agent.score, agent.best_score, agent.noise_scale), end="")  # [debug]
            result = [i_episode] + [agent.total_reward] + [agent.score] \
                   + [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) \
                   + list(action)
            for ii in range(len(labels)):
                results[labels[ii]].append(result[ii])
            break
    sys.stdout.flush()
# Out:
# Episode =  622, score =   2.548 (best =   2.919), noise_scale = 3.2625
# F:\OneDrive - Schlumberger\OpenCourse\Udacity_Deep Learning Nanodegree\RL-Quadcopter-2\physics_sim.py:121: RuntimeWarning: overflow encountered in double_scalars
#   C_T = max(.12 - .07*max(0, J)-.1*max(0, J)**2, 0)
# F:\OneDrive - Schlumberger\OpenCourse\Udacity_Deep Learning Nanodegree\RL-Quadcopter-2\physics_sim.py:95: RuntimeWarning: overflow encountered in multiply
#   drag_moment =  self.C_d * 0.5 * self.rho * self.angular_v * np.absolute(self.angular_v) * self.areas * self.dims * self.dims
# F:\OneDrive - Schlumberger\OpenCourse\Udacity_Deep Learning Nanodegree\RL-Quadcopter-2\physics_sim.py:138: RuntimeWarning: invalid value encountered in remainder
#   angles = (angles + 2 * np.pi) % (2 * np.pi)
# F:\OneDrive - Schlumberger\OpenCourse\Udacity_Deep Learning Nanodegree\RL-Quadcopter-2\physics_sim.py:139: RuntimeWarning: invalid value encountered in add
#   self.angular_v = self.angular_v + self.angular_accels * self.dt
# Episode = 1000, score =  -0.947 (best =   2.919), noise_scale = 3.2

# %%
plt.plot(results_last_episode['time'], results_last_episode['x'], label='x')
plt.plot(results_last_episode['time'], results_last_episode['y'], label='y')
plt.plot(results_last_episode['time'], results_last_episode['z'], label='z')
plt.legend()
_ = plt.ylim()

# %%
## running mean function
def running_mean(x, N):
    cumsum = np.cumsum(np.insert(x, 0, 0))
    return (cumsum[N:] - cumsum[:-N]) / N

# %%
## plot the rewards.
smoothed_rews = running_mean(results['total_reward'], 10)
plt.plot(results['i_episode'][-len(smoothed_rews):], smoothed_rews, label='total reward (running mean)')
plt.plot(results['i_episode'], results['total_reward'], color='grey', alpha=0.3, label='total reward')
plt.legend()
_ = plt.ylim()
plt.show()

# %% [markdown]
# This agent should perform very poorly on this task.  And that's where you come in!

# %% [markdown]
# ## Define the Task, Design the Agent, and Train Your Agent!
#
# Amend `task.py` to specify a task of your choosing.  If you're unsure what kind of task to specify, you may like to teach your quadcopter to takeoff, hover in place, land softly, or reach a target pose.
#
# After specifying your task, use the sample agent in `agents/policy_search.py` as a template to define your own agent in `agents/agent.py`.  You can borrow whatever you need from the sample agent, including ideas on how you might modularize your code (using helper methods like `act()`, `learn()`, `reset_episode()`, etc.).
#
# Note that it is **highly unlikely** that the first agent and task that you specify will learn well.  You will likely have to tweak various hyperparameters and the reward function for your task until you arrive at reasonably good behavior.
#
# As you develop your agent, it's important to keep an eye on how it's performing. Use the code above as inspiration to build in a mechanism to log/save the total rewards obtained in each episode to file.  If the episode rewards are gradually increasing, this is an indication that your agent is learning.

# %%
from task import Task
from agents.agent import DDPG

## TODO: Train your agent here.
num_episodes = 1000

# init_pose_height = np.random.uniform(0.5, 1.5)
init_pose = np.array([0., 0., 1., 0., 0., 0.])
init_velocities = np.array([0., 0., 0.])
init_angle_velocities = np.array([0., 0., 0.])
target_pos = np.array([0., 0., 10.])
task = Task(init_pose, init_velocities, init_angle_velocities, target_pos=target_pos)

agent = DDPG(task)

file_output = 'data.csv'

# Setup
done = False
labels = ['i_episode', 'total_reward', 'score', 'time', 'x', 'y', 'z', 'phi', 'theta', 'psi',
          'x_velocity', 'y_velocity', 'z_velocity', 'phi_velocity', 'theta_velocity', 'psi_velocity',
          'rotor_speed1', 'rotor_speed2', 'rotor_speed3', 'rotor_speed4']
results = {x: [] for x in labels}
results_last_episode = {x: [] for x in labels}

# Run the simulation, and save the results.
with open(file_output, 'w') as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(labels)

    for i_episode in range(1, num_episodes + 1):
        state = agent.reset_episode()  # start a new episode
        while True:
            action = agent.act(state)
            next_state, reward, done = task.step(action)
            agent.step(action, reward, next_state, done)
            state = next_state
            if i_episode == num_episodes:
                to_write = [i_episode] + [agent.total_reward] + [agent.score] \
                           + [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) \
                           + list(action)
                for ii in range(len(labels)):
                    results_last_episode[labels[ii]].append(to_write[ii])
            if done:
                print("Episode = {:4d}, score = {:7.3f} (best = {:7.3f})".format(i_episode, agent.score, agent.best_score))
                to_write = [i_episode] + [agent.total_reward] + [agent.score] \
                           + [task.sim.time] + list(task.sim.pose) + list(task.sim.v) + list(task.sim.angular_v) \
                           + list(action)
                for ii in range(len(labels)):
                    results[labels[ii]].append(to_write[ii])
                writer.writerow(to_write)
                break
# Out:
# C:\ProgramData\Anaconda2\envs\python3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Episode =    1, score =   0.000 (best =    -inf)
# Episode =    2, score =   0.000 (best =    -inf)
# Episode =    3, score =   0.000 (best =    -inf)
# Episode =    4, score =   0.000 (best =    -inf)
# Episode =    5, score =  -1.774 (best =  -0.090)
# Episode =    6, score =  -2.049 (best =  -0.090)
# Episode =    7, score =  -1.830 (best =  -0.090)
# Episode =    8, score =  -1.647 (best =  -0.090)
# Episode =    9, score =  -2.382 (best =  -0.090)
# Episode =   10, score =  -2.048 (best =  -0.090)
# Episode =   11, score =  -2.071 (best =  -0.090)
# Episode =   12, score =  -2.092 (best =  -0.090)
# Episode =   13, score =  -2.121 (best =  -0.090)
# Episode =   14, score =  -2.220 (best =  -0.090)
# Episode =   15, score =  -2.095 (best =  -0.090)
# Episode =   16, score =  -2.025 (best =  -0.090)
# Episode =   17, score =  -1.995 (best =  -0.090)
# Episode =   18, score =  -2.026 (best =  -0.090)
# Episode =   19, score =  -2.058 (best =  -0.090)
# Episode =   20, score =  -2.044 (best =  -0.090)
# Episode =   21, score =  -1.970 (best =  -0.090)
# Episode =   22, score =  -1.972 (best =  -0.090)
# Episode =   23, score =  -1.955 (best =  -0.090)
# Episode =   24, score =  -1.963 (best =  -0.090)
# Episode =   25, score =  -1.875 (best =  -0.090)
# Episode =   26, score =  -1.837 (best =  -0.012)
# Episode =   27, score =  -1.829 (best =   0.118)
# Episode =   28, score =  -1.686 (best =   0.209)
# Episode =   29, score =  -1.708 (best =   0.684)
# Episode =   30, score =  -1.428 (best =   1.024)
# Episode =   31, score =  -1.464 (best =   1.241)
# Episode =   32, score =  -1.284 (best =   1.376)
# Episode =   33, score =  -1.318 (best =   1.376)
# Episode =   34, score =  -1.284 (best =   1.376)
# Episode =   35, score =  -1.272 (best =   1.379)
# Episode =   36, score =  -1.239 (best =   1.436)
# Episode =   37, score =  -1.181 (best =   1.483)
# Episode =   38, score =  -1.192 (best =   1.540)
# Episode =   39, score =  -1.202 (best =   1.588)
# Episode =   40, score =  -1.089 (best =   1.633)
# Episode =   41, score =  -1.100 (best =   1.667)
# Episode =  495, score =   2.920 (best =   2.977)
# Episode =  496, score =   2.954 (best =   2.977)
# Episode =  497, score =   1.137 (best =   2.977)
# Episode =  498, score =   1.668 (best =   2.977)
# Episode =  499, score =   2.882 (best =   2.977)
# Episode =  500, score =   1.756 (best =   2.977)
# Episode =  501, score =   2.776 (best =   2.977)
# Episode =  502, score =   2.977 (best =   2.977)
# Episode =  503, score =   0.676 (best =   2.977)
# Episode =  504, score =   2.911 (best =   2.977)
# Episode =  505, score =   2.977 (best =   2.977)
# Episode =  506, score =   1.876 (best =   2.977)
# Episode =  507, score =   1.301 (best =   2.977)
# Episode =  508, score =   2.977 (best =   2.977)
# Episode =  509, score =   2.977 (best =   2.977)
# Episode =  510, score =   1.193 (best =   2.977)
# Episode =  511, score =   2.977 (best =   2.977)
# Episode =  512, score =   2.977 (best =   2.977)
# Episode =  513, score =   1.899 (best =   2.977)
# Episode =  514, score =   2.910 (best =   2.977)
# Episode =  515, score =   2.904 (best =   2.977)
# Episode =  516, score =   1.203 (best =   2.977)
# Episode =  517, score =   2.661 (best =   2.977)
# Episode =  518, score =   2.873 (best =   2.977)
# Episode =  519, score =   1.532 (best =   2.977)
# Episode =  520, score =   2.917 (best =   2.977)
# Episode =  521, score =   2.977 (best =   2.977)
# Episode =  522, score =   2.212 (best =   2.977)
# Episode =  523, score =   2.977 (best =   2.977)
# Episode =  524, score =   2.977 (best =   2.977)
# Episode =  525, score =   2.249 (best =   2.977)
# Episode =  526, score =   2.906 (best =   2.977)
# Episode =  527, score =   2.977 (best =   2.977)
# Episode =  528, score =   2.915 (best =   2.977)
# Episode =  529, score =   1.819 (best =   2.977)
# Episode =  530, score =   2.900 (best =   2.977)
# Episode =  531, score =   2.909 (best =   2.977)
# Episode =  532, score =   1.682 (best =   2.977)
# Episode =  533, score =   2.900 (best =   2.977)
# Episode =  534, score =   2.397 (best =   2.977)
# Episode =  535, score =   1.333 (best =   2.977)
# Episode =  536, score =   2.977 (best =   2.977)
# Episode =  537, score =   1.281 (best =   2.977)
# Episode =  538, score =   2.915 (best =   2.977)
# Episode =  539, score =   2.773 (best =   2.977)
# Episode =  540, score =   2.927 (best =   2.977)
# Episode =  541, score =   2.242 (best =   2.977)
# Episode =  542, score =   1.433 (best =   2.977)
# Episode =  543, score =   2.918 (best =   2.977)
# Episode =  544, score =   2.919 (best =   2.977)
# Episode =  545, score =   2.920 (best =   2.977)
# Episode =  546, score =   2.977 (best =   2.977)
# Episode =  547, score =   2.840 (best =   2.977)
# Episode =  548, score =   1.414 (best =   2.977)
# Episode =  549, score =   1.858 (best =   2.977)
# Episode =  550, score =   2.977 (best =   2.977)
# Episode =  551, score =   2.954 (best =   2.977)
# Episode =  552, score =   0.532 (best =   2.977)
# Episode =  553, score =   1.504 (best =   2.977)
# Episode =  554, score =   1.678 (best =   2.977)
# Episode =  555, score =   2.554 (best =   2.977)
# Episode =  556, score =   1.917 (best =   2.977)
# Episode =  557, score =   2.316 (best =   2.977)
# Episode =  558, score =   2.595 (best =   2.977)
# Episode =  559, score =   2.906 (best =   2.977)
# Episode =  560, score =   2.912 (best =   2.977)
# Episode =  756, score =   2.977 (best =   2.977)
# Episode =  757, score =   2.735 (best =   2.977)
# Episode =  758, score =   1.108 (best =   2.977)
# Episode =  759, score =   2.912 (best =   2.977)
# Episode =  760, score =   2.977 (best =   2.977)
# Episode =  761, score =   2.922 (best =   2.977)
# Episode =  762, score =   2.918 (best =   2.977)
# Episode =  763, score =   1.468 (best =   2.977)
# Episode =  764, score =   2.901 (best =   2.977)
# Episode =  765, score =   2.000 (best =   2.977)
# Episode =  766, score =   2.913 (best =   2.977)
# Episode =  767, score =   2.918 (best =   2.977)
# Episode =  768, score =   2.977 (best =   2.977)
# Episode =  769, score =   2.977 (best =   2.977)
# Episode =  770, score =   2.977 (best =   2.977)
# Episode =  771, score =   1.146 (best =   2.977)
# Episode =  772, score =   2.898 (best =   2.977)
# Episode =  773, score =   2.532 (best =   2.977)
# Episode =  774, score =   2.913 (best =   2.977)
# Episode =  775, score =   2.906 (best =   2.977)
# Episode =  776, score =   1.498 (best =   2.977)
# Episode =  777, score =   2.920 (best =   2.977)
# Episode =  778, score =   2.977 (best =   2.977)
# Episode =  779, score =   2.977 (best =   2.977)
# Episode =  780, score =   1.344 (best =   2.977)
# Episode =  781, score =   1.695 (best =   2.977)
# Episode =  782, score =   2.977 (best =   2.977)
# Episode =  783, score =   2.003 (best =   2.977)
# Episode =  784, score =   0.966 (best =   2.977)
# Episode =  785, score =   2.866 (best =   2.977)
# Episode =  786, score =   2.898 (best =   2.977)
# Episode =  787, score =   2.977 (best =   2.977)
# Episode =  788, score =   2.916 (best =   2.977)
# Episode =  789, score =   2.898 (best =   2.977)
# Episode =  790, score =   2.239 (best =   2.977)
# Episode =  791, score =   2.923 (best =   2.977)
# Episode =  792, score =   2.977 (best =   2.977)
# Episode =  793, score =   2.917 (best =   2.977)
# Episode =  794, score =   2.902 (best =   2.977)
# Episode =  795, score =   0.802 (best =   2.977)
# Episode =  796, score =   2.976 (best =   2.977)
# Episode =  797, score =   2.922 (best =   2.977)
# Episode =  798, score =   2.922 (best =   2.977)
# Episode =  799, score =   2.973 (best =   2.977)
# Episode =  800, score =   2.927 (best =   2.977)
# Episode =  801, score =   2.973 (best =   2.977)
# Episode =  802, score =   2.977 (best =   2.977)
# Episode =  803, score =   2.977 (best =   2.977)
# Episode =  804, score =   2.977 (best =   2.977)
# Episode =  805, score =   2.977 (best =   2.977)
# Episode =  806, score =   2.977 (best =   2.977)
# Episode =  807, score =   0.884 (best =   2.977)
# Episode =  808, score =   2.977 (best =   2.977)
# Episode =  809, score =   2.266 (best =   2.977)
# Episode =  810, score =   2.977 (best =   2.977)
# Episode =  811, score =   2.977 (best =   2.977)
# Episode =  812, score =   2.920 (best =   2.977)
# Episode =  813, score =   0.964 (best =   2.977)
# Episode =  814, score =   2.903 (best =   2.977)
# Episode =  815, score =   2.916 (best =   2.977)
# Episode =  816, score =   2.953 (best =   2.977)
# Episode =  817, score =   2.866 (best =   2.977)
# Episode =  818, score =   2.440 (best =   2.977)
# Episode =  819, score =   2.903 (best =   2.977)
# Episode =  820, score =   2.917 (best =   2.977)
# Episode =  821, score =   1.172 (best =   2.977)
# Episode =  822, score =   2.911 (best =   2.977)
# Episode =  823, score =   2.903 (best =   2.977)
# Episode =  824, score =   2.909 (best =   2.977)
# Episode =  825, score =   2.977 (best =   2.977)
# Episode =  826, score =   2.772 (best =   2.977)
# Episode =  827, score =   1.983 (best =   2.977)
# Episode =  828, score =   2.450 (best =   2.977)
# Episode =  829, score =   2.591 (best =   2.977)
# Episode =  830, score =   1.335 (best =   2.977)
# Episode =  831, score =   2.977 (best =   2.977)
# Episode =  832, score =   2.977 (best =   2.977)
# Episode =  833, score =   1.855 (best =   2.977)
# Episode =  834, score =   2.907 (best =   2.977)
# Episode =  835, score =   2.702 (best =   2.977)
# Episode =  836, score =   1.199 (best =   2.977)
# Episode =  837, score =   2.882 (best =   2.977)
# Episode =  838, score =   2.977 (best =   2.977)
# Episode =  839, score =   1.667 (best =   2.977)
# Episode =  840, score =   2.911 (best =   2.977)
# Episode =  841, score =   2.977 (best =   2.977)
# Episode =  842, score =   2.909 (best =   2.977)
# Episode =  843, score =   1.846 (best =   2.977)
# Episode =  844, score =   1.797 (best =   2.977)
# Episode =  845, score =   2.765 (best =   2.977)
# Episode =  846, score =   2.913 (best =   2.977)
# Episode =  847, score =   2.149 (best =   2.977)
# Episode =  848, score =   2.977 (best =   2.977)
# Episode =  849, score =   2.903 (best =   2.977)
# Episode =  850, score =   2.977 (best =   2.977)
# Episode =  851, score =   1.805 (best =   2.977)
# Episode =  852, score =   2.920 (best =   2.977)
# Episode =  853, score =   2.543 (best =   2.977)
# Episode =  854, score =   1.097 (best =   2.977)
# Episode =  855, score =   1.795 (best =   2.977)
# Episode =  856, score =   2.916 (best =   2.977)
# Episode =  857, score =   2.977 (best =   2.977)
# Episode =  858, score =   2.906 (best =   2.977)
# Episode =  859, score =   2.977 (best =   2.977)
# Episode =  860, score =   2.543 (best =   2.977)
# Episode =  861, score =   2.977 (best =   2.977)
# Episode =  862, score =   2.977 (best =   2.977)
# Episode =  863, score =   1.569 (best =   2.977)
# Episode =  864, score =   2.050 (best =   2.977)
# Episode =  865, score =   2.919 (best =   2.977)
# Episode =  866, score =   2.977 (best =   2.977)
# Episode =  867, score =   2.838 (best =   2.977)
# Episode =  868, score =   2.913 (best =   2.977)
# Episode =  869, score =   2.977 (best =   2.977)
# Episode =  870, score =   0.988 (best =   2.977)
# Episode =  871, score =   2.921 (best =   2.977)
# Episode =  872, score =   2.908 (best =   2.977)
# Episode =  873, score =   1.414 (best =   2.977)
# Episode =  874, score =   0.951 (best =   2.977)
# Episode =  875, score =   2.916 (best =   2.977)
# Episode =  876, score =   2.977 (best =   2.977)
# Episode =  877, score =   2.911 (best =   2.977)
# Episode =  878, score =   2.903 (best =   2.977)
# Episode =  879, score =   2.902 (best =   2.977)
# Episode =  880, score =   2.977 (best =   2.977)
# Episode =  881, score =   2.917 (best =   2.977)
# Episode =  882, score =   2.916 (best =   2.977)
# Episode =  883, score =   2.977 (best =   2.977)
# Episode =  884, score =   2.977 (best =   2.977)
# Episode =  885, score =   2.977 (best =   2.977)
# Episode =  886, score =   2.917 (best =   2.977)
# Episode =  887, score =   2.924 (best =   2.977)
# Episode =  888, score =   2.977 (best =   2.977)
# Episode =  889, score =   2.977 (best =   2.977)
# Episode =  890, score =   1.179 (best =   2.977)
# Episode =  891, score =   2.903 (best =   2.977)
# Episode =  892, score =   2.977 (best =   2.977)
# Episode =  893, score =   2.908 (best =   2.977)
# Episode =  894, score =   2.902 (best =   2.977)
# Episode =  895, score =   2.977 (best =   2.977)
# Episode =  896, score =   2.903 (best =   2.977)
# Episode =  897, score =   0.946 (best =   2.977)
# Episode =  898, score =   2.977 (best =   2.977)
# Episode =  899, score =   2.977 (best =   2.977)
# Episode =  900, score =   1.521 (best =   2.977)
# Episode =  901, score =   2.977 (best =   2.977)
# Episode =  902, score =   1.471 (best =   2.977)
# Episode =  903, score =   2.977 (best =   2.977)
# Episode =  904, score =   1.135 (best =   2.977)
# Episode =  905, score =   2.717 (best =   2.977)
# Episode =  906, score =   2.918 (best =   2.977)
# Episode =  907, score =   1.248 (best =   2.977)
# Episode =  908, score =   0.976 (best =   2.977)
# Episode =  909, score =   2.977 (best =   2.977)
# Episode =  910, score =   2.908 (best =   2.977)
# Episode =  911, score =   2.920 (best =   2.977)
# Episode =  912, score =   2.977 (best =   2.977)
# Episode =  913, score =   1.522 (best =   2.977)
# Episode =  914, score =   1.946 (best =   2.977)
# Episode =  915, score =   1.706 (best =   2.977)
# Episode =  916, score =   1.320 (best =   2.977)
# Episode =  917, score =   2.921 (best =   2.977)
# Episode =  918, score =   2.553 (best =   2.977)
# Episode =  919, score =   2.918 (best =   2.977)
# Episode =  920, score =   2.924 (best =   2.977)
# Episode =  921, score =   1.748 (best =   2.977)
# Episode =  922, score =   2.973 (best =   2.977)
# Episode =  923, score =   2.977 (best =   2.977)
# Episode =  924, score =   2.117 (best =   2.977)
# Episode =  925, score =   1.401 (best =   2.977)
# Episode =  926, score =   2.977 (best =   2.977)
# Episode =  927, score =   1.269 (best =   2.977)
# Episode =  928, score =   2.977 (best =   2.977)
# Episode =  929, score =   2.912 (best =   2.977)
# Episode =  930, score =   2.927 (best =   2.977)
# Episode =  931, score =   2.913 (best =   2.977)
# Episode =  932, score =   2.922 (best =   2.977)
# Episode =  933, score =   2.308 (best =   2.977)
# Episode =  934, score =   1.697 (best =   2.977)
# Episode =  935, score =   2.909 (best =   2.977)
# Episode =  936, score =   1.866 (best =   2.977)
# Episode =  937, score =   2.908 (best =   2.977)
# Episode =  938, score =   2.977 (best =   2.977)
# Episode =  939, score =   2.977 (best =   2.977)
# Episode =  940, score =   2.903 (best =   2.977)
# Episode =  941, score =   2.977 (best =   2.977)
# Episode =  942, score =   2.794 (best =   2.977)
# Episode =  943, score =   2.667 (best =   2.977)
# Episode =  944, score =   2.977 (best =   2.977)
# Episode =  945, score =   2.909 (best =   2.977)
# Episode =  946, score =   2.601 (best =   2.977)
# Episode =  947, score =   1.270 (best =   2.977)
# Episode =  948, score =   2.915 (best =   2.977)
# Episode =  949, score =   2.475 (best =   2.977)
# Episode =  950, score =   1.915 (best =   2.977)
# Episode =  951, score =   2.977 (best =   2.977)
# Episode =  952, score =   2.916 (best =   2.977)
# Episode =  953, score =   1.295 (best =   2.977)
# Episode =  954, score =   2.977 (best =   2.977)
# Episode =  955, score =   2.802 (best =   2.977)
# Episode =  956, score =   2.655 (best =   2.977)
# Episode =  957, score =   2.977 (best =   2.977)
# Episode =  958, score =   2.903 (best =   2.977)
# Episode =  959, score =   1.729 (best =   2.977)
# Episode =  960, score =   1.871 (best =   2.977)
# Episode =  961, score =   1.590 (best =   2.977)
# Episode =  962, score =   2.916 (best =   2.977)
# Episode =  963, score =   2.913 (best =   2.977)
# Episode =  964, score =   2.977 (best =   2.977)
# Episode =  965, score =   1.216 (best =   2.977)
# Episode =  966, score =   0.878 (best =   2.977)
# Episode =  967, score =   2.489 (best =   2.977)
# Episode =  968, score =   2.977 (best =   2.977)
# Episode =  969, score =   2.915 (best =   2.977)
# Episode =  970, score =   2.686 (best =   2.977)
# Episode =  971, score =   1.780 (best =   2.977)
# Episode =  972, score =   1.667 (best =   2.977)
# Episode =  973, score =   2.923 (best =   2.977)
# Episode =  974, score =   2.908 (best =   2.977)
# Episode =  975, score =   2.909 (best =   2.977)
# Episode =  976, score =   2.916 (best =   2.977)
# Episode =  977, score =   1.299 (best =   2.977)
# Episode =  978, score =   2.977 (best =   2.977)
# Episode =  979, score =   1.960 (best =   2.977)
# Episode =  980, score =   2.159 (best =   2.977)
# Episode =  981, score =   1.768 (best =   2.977)
# Episode =  982, score =   2.905 (best =   2.977)
# Episode =  983, score =   2.903 (best =   2.977)
# Episode =  984, score =   2.977 (best =   2.977)
# Episode =  985, score =   2.900 (best =   2.977)
# Episode =  986, score =   2.917 (best =   2.977)
# Episode =  987, score =   2.911 (best =   2.977)
# Episode =  988, score =   2.711 (best =   2.977)
# Episode =  989, score =   2.377 (best =   2.977)
# Episode =  990, score =   1.369 (best =   2.977)
# Episode =  991, score =   2.912 (best =   2.977)
# Episode =  992, score =   2.911 (best =   2.977)
# Episode =  993, score =   2.977 (best =   2.977)
# Episode =  994, score =   2.977 (best =   2.977)
# Episode =  995, score =   0.534 (best =   2.977)
# Episode =  996, score =   2.924 (best =   2.977)
# Episode =  997, score =   2.906 (best =   2.977)
# Episode =  998, score =   1.971 (best =   2.977)
# Episode =  999, score =   2.977 (best =   2.977)
# Episode = 1000, score =   2.929 (best =   2.977)

# %% [markdown]
# ## Plot the Rewards
#
# Once you are satisfied with your performance, plot the episode rewards, either from a single run, or averaged over multiple runs.

# %%
## TODO: Plot the last episode
plt.plot(results_last_episode['time'], results_last_episode['x'], label='x')
plt.plot(results_last_episode['time'], results_last_episode['y'], label='y')
plt.plot(results_last_episode['time'], results_last_episode['z'], label='z')
plt.legend()
_ = plt.ylim()
plt.show()

# %%
## TODO: Plot the rewards.
smoothed_rews = running_mean(results['total_reward'], 10)
plt.plot(results['i_episode'][-len(smoothed_rews):], smoothed_rews, label='total reward (running mean)')
plt.plot(results['i_episode'], results['total_reward'], color='grey', alpha=0.3, label='total reward')
plt.legend()
_ = plt.ylim()
plt.show()

# %% [markdown]
# ## Reflections
#
# **Question 1**: Describe the task that you specified in `task.py`.  How did you design the reward function?
#
# **Answer**:
#
# The task I specified is to take off the quadcopter.
#
# I tried many reward functions and most of them converged to the states where the quadcopter dropped to the ground. However, I still specified the following reward function that works:
#
# $$
# R(t) =
# \begin{cases}
#     \tanh{\left(1-\min{\left(0.5*{\left\|\mathbf{p}_t - \mathbf{p}^*\right\|}_2, 2\right)}+\mathbf{v}_z\right)}&, \text{not done}\\
#     -1&, \text{done and crashed}\\
#     10&, \text{done and } {\left\|\mathbf{p}_t - \mathbf{p}^*\right\|}_2 \leq 2
# \end{cases}
# $$
#
# where $R(t)$ is the reward function in terms of the iteration index $t$ at one episode, $\mathbf{p}_t$ is the current position, $\mathbf{p}^*$ is the target position as pre-defined, $\left\| \cdot \right\|_2$ is the $\ell_2$-norm, so ${\left\|\mathbf{p}_t - \mathbf{p}^*\right\|}_2$ is the Euclidean distance between the current position $\mathbf{p}_t$ and the pre-defined target position $\mathbf{p}^*$. The loss introduced by the Euclidean distance is restricted to no smaller than $-2$ by $-\min{\left(0.5*{\left\|\mathbf{p}_t - \mathbf{p}^*\right\|}_2, 2\right)}$. Furthermore, the upward velocity $\mathbf{v}_z$ is also included in $R(t)$ as it also deserves a bonus for the task of taking off the quadcopter if it is positive as well as a penality if it is negative. Finally, $\tanh{\left(\cdot\right)}$ is used to restrict the overall reward function values between $-1$ and $1$.

# %% [markdown]
# **Question 2**: Discuss your agent briefly, using the following questions as a guide:
#
# - What learning algorithm(s) did you try? What worked best for you?
# - What was your final choice of hyperparameters (such as $\alpha$, $\gamma$, $\epsilon$, etc.)?
# - What neural network architecture did you use (if any)? Specify layers, sizes, activation functions, etc.
#
# **Answer**:
#
# I used the Actor-Critic algorithms with value function approximation for such reinforcement learning problem because both the state and action spaces are continuous. I started with the code templates provided in the project page.
#
# My current choices of hyperparameters are follows (acknowledgement to the reference in the Section 7. Experiment Details of [Continuous control with deep reinforcement learning](https://arxiv.org/abs/1509.02971)):
#
# - The learning rate $\alpha_a = 0.0001$ for Actor and $\alpha_c = 0.0005$ for Critic.
# - The dropout rate is $0.2$ for both Actor and Critic models.
# - The discount factor $\gamma = 0.99$.
# - The soft update factor $\tau = 0.001$.
# - An $\ell_2$-norm weight regularization penalty (weight decay) of $0.01$ is affixed to the layer that produces Q values by `Q_values = layers.Dense(units=1, name='q_values', kernel_regularizer=regularizers.l2(0.01))(net)`.
# - I do not have an $\epsilon$ parameter in my algorithm as I do not use an $\epsilon$-greedy algorithm.
#
# The network structures for Actor and Critic are as follows (`plot_model` is used to plot the Keras model, and note that the ReLU activation function is included in all of the Dense layers by having `activation='relu'` in the argument list of `Dense`):
# <h1><center>Actor model</center></h1>
# <img src="actor_model.png">
# <hr>
# <h1><center>Critic model</center></h1>
# <img src="critic_model.png">

# %% [markdown]
# **Question 3**: Using the episode rewards plot, discuss how the agent learned over time.
#
# - Was it an easy task to learn or hard?
# - Was there a gradual learning curve, or an aha moment?
# - How good was the final performance of the agent? (e.g. mean rewards over the last 10 episodes)
#
# **Answer**:
#
# It was indeed a hard task to learn.
#
# The result does not appear to have a gradual learning curve. There seems to have an "aha" moment if everything goes right.
#
# The final performance of the agent gets converged and the mean rewards over the last 10 episodes by `running_mean(results['total_reward'], 10)` is around 200.

# %% [markdown]
# **Question 4**: Briefly summarize your experience working on this project. You can use the following prompts for ideas.
#
# - What was the hardest part of the project? (e.g. getting started, plotting, specifying the task, etc.)
# - Did you find anything interesting in how the quadcopter or your agent behaved?
#
# **Answer**:
#
# I think the hardest part of the project is (1) getting started, (2) design the reward function given my selected task, and (3) selecting appropriate structures and hyperparameters for the neural networks, as well as the parameters for the noise.
#
# I found one interesting point is that the `total_reward` sometime suddenly dropped from high values where the quadcopter seems learn how to fly to very low values where the quadcopter just simply dropped due to the change of the action comprised of the 4 rotor speeds. It frastrates me. Similarly, after another dozens or hundreds of episodes, the `total_reward` goes back to higher values again, which becomes another "aha" moment for me. These phenomenons indicate that it could be difficult to let the action value function $Q$ converge.
#
# Also, it seems that the trajectory of the quadcopter as well as the `total_reward` is very sensitive to the action comprised of the 4 rotor speeds, maybe due to the dynamic nature of the quadcopter.
